# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import requests
import re
import urllib.parse

fileUrl = input("Entrer l'url du fichier :")

fileExtension = '.' + fileUrl.split('.')[-1]

filenameLabel = re.search('/(.*)' + fileExtension , s)

urllib.parse.unquote(filenameLabel)

urllib.parse.unquote(filenameLabel).replace(" ","") 

filename = filenameLabel + fileExtension 

filePath = "/content/drive/MyDrive/Download/" + filename

data = requests.get(fileUrl)

with open(filePath, 'wb')as file: file.write(data.content)
