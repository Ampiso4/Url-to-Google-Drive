# %%
from google.colab import drive
from google.colab import files
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !mkdir "/content/drive/MyDrive/Download"

# %%
import requests
import shutil

fileUrl = input("Entrer l'url du fichier :")

filename = fileUrl.split('/')[-1]

filename = filename.replace("%20","") 

print(filename)

filePath = "/content/drive/MyDrive/Download/" + filename

data = requests.get(fileUrl)

with open(filePath, 'wb')as file: file.write(data.content)

print(" FINISH DOWNLOAD FILE TO DRIVE")


WannaSaveToLocal = input("Input 'Y'/'y' to download file in your local. Otherwise, leave blank. ")

if WannaSaveToLocal == 'Y' or WannaSaveToLocal == 'y':
    zip_name = input("Your file will be downloaded")
    files.download(filePath)
    print(" FINISH DOWNLOAD FILE TO LOCAL")



print(' ALL DONE ')
